# %%
import requests
import sqlite3
from bs4 import BeautifulSoup
import MeCab as mc
import gensim
from gensim.models import Word2Vec
from gensim import matutils
from gensim.corpora.dictionary import Dictionary
from sklearn import ensemble
from sklearn.model_selection import train_test_split

# %%
conn = None

#  データベースに接続する
def connect():
    global conn
    conn = sqlite3.connect('./yahoonews.db')

def close():
    conn.close()
    
def create_table():
    conn.execute('DROP TABLE IF EXISTS news')
    conn.execute("""CREATE TABLE news (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            title text,
            category text
            )""")

#  Countriesテーブルにレコードを挿入
def load(title, category):
    conn.execute(
        'INSERT INTO news (title, category) VALUES (?, ?)', (title, category))
    conn.commit()
    
def get_all_title(limit, offset=0):
    return [record[0] for record in 
               conn.execute(
            'SELECT title FROM news LIMIT ? OFFSET ?',
            (limit, offset))]

# %%
connect()
create_table()
close()

# %%
url = "https://news.yahoo.co.jp/"

r  = requests.get(url)
bs = BeautifulSoup(r.text, "html.parser")

# %%
p    = bs.find("p", class_="topicsList_button_more")
link = p.find("a").get("href")

r = requests.get(link)
bs = BeautifulSoup(r.text, "html.parser")
bs

# %%
category_ul = bs.find("ul", class_="cateTab")
category_list = category_ul.find_all("a")
sports_link = category_list[5].get("href")
it_link = category_list[6].get("href")

# %%
# 欲しいカテゴリーのurlを渡すとリンク先から1000件分のニュースのタイトルの文字列リストを返す
def get_title_list(url):
    header = "https://news.yahoo.co.jp"
    title_list = []
    for i in range(50):
        r  = requests.get(header + url)
        bs = BeautifulSoup(r.text , "html.parser")
        
        dl_list = bs.find_all("dl", class_="title")
        page_list = []
        for dl in dl_list:
            page_list.append(dl.dt.text)
        title_list += page_list    
        
        url = bs.find("li", class_="next")
        url = url.find("a").get("href")
    return title_list
    
def load_list(title_list, category):
    for title in title_list:
        load(title, category)

# %%
sports_title = get_title_list(sport_link)
it_title = get_title_list(it_link)

connect()
load_list(sports_title, "スポーツ")
load_list(it_title, "IT")
close()

# %%
def mecab_analysis(texts):
    t = mc.Tagger("-d /usr/lib/x86_64-linux-gnu/mecab/dic/mecab-ipadic-neologd")
    t.parse('')
    output = []
    node =  t.parseToNode(texts)  
    while node:
        if node.surface != "":  # ヘッダとフッタを除外
            word_type = node.feature.split(",")[0]
            if word_type in ['名詞', "形容詞", "動詞"]:
                output.append(node.surface)
        node = node.next
        if node is None:
            break
    return output

# %%
connect()
title_list = get_all_title(-1)

wakati_list = [mecab_analysis(title) for title in title_list]

# %%
wakati_list
# Out:
# [['マー君', 'ももクロ', '観戦', '敗戦'],
#  ['平尾誠二', 'さん', '娘', '父'],
#  ['U', '20日', '大人', 'サッカー', '必要'],
#  ['大谷', 'MLB', '球宴', 'DH', '候補', '入り'],
#  ['ももクロ', 'マー君', '観戦', '興奮'],
#  ['松坂', '来月21日', '1軍', '復帰'],
#  ['大坂', '初戦突破', '人生', '一番', '緊張'],
#  ['仏', '大', '坂', '大逆転', '初戦突破'],
#  ['幻', '80年', '五輪', '代表', '笹田', '氏', '死去'],
#  ['仏', 'OP', '大坂なおみ', '1回戦'],
#  ['八百長', 'レアル', 'DF', 'ら', '逮捕'],
#  ['浦和', '監督解任', '後任', '組長'],
#  ['羽生結弦', '確か', '回復'],
#  ['川内優輝', '世界陸上', '代表復帰'],
#  ['青木宣親', '丸刈り', '体', '鼓舞'],
#  ['中日', '松坂', '257日', 'ぶり', '実戦', '登板'],
#  ['188cm', '下手', 'SB', '右腕'],
#  ['相撲', '座布団', '罪'],
#  ['大坂', '赤土', '克服'],
#  ['大谷', '技あり', '安打', '二', '盗', '失敗'],
#  ['五輪', 'チケ', '申し込み', 'きょう'],
#  ['ドラフト', '指名', '優先', '権', '変更'],
#  ['2軍', '戦', '100', '球', '輝', '星', '昇格', '条件'],
#  ['横審', '混乱', '審判', '部', '苦言'],
#  ['全豪', 'V', 'クビトバ', '仏', '棄権'],
#  ['広島', '浮上', 'きっかけ', '丸', '2ラン'],
#  ['広島', '浮上', '4月', '丸', '2ラン', '覚醒'],
#  ['夏場所', '大統領', '視聴率', '26.3%'],
#  ['単勝', '93倍', '伏兵', 'ダービー', 'V'],
#  ['朝乃', '山', '親方', 'クーラー'],
#  ['何', '本田圭佑'],
#  ['マエケン', '先発', '復帰', '今季', '6勝', '目'],
#  ['U', '20日', 'メキシコ', '3発', '快勝'],
#  ['J', 'ビスマルク', 'ポーズ'],
#  ['仏', 'OP', '錦織圭', '初戦突破'],
#  ['FW', 'ロニー', '母国', '試合中', '逮捕'],
#  ['御嶽海', '苦言', '朝乃', '山かわ', 'そう'],
#  ['速報', '仏', 'OP', '錦織圭', '1回戦'],
#  ['蘭', '主審', 'ゴール', '抗議'],
#  ['米大統領', '杯', '来年以降', '授与'],
#  ['G', '元木', 'コーチ', '判断'],
#  ['頭', '真っ白', '浜中', 'ダービー', '制覇'],
#  ['J1', '神戸', '連敗', '脱出'],
#  ['ロジャーバローズ', 'ダービー', 'V'],
#  ['伊藤雅雪', '0', '-3', '痛恨', '王座', '陥落'],
#  ['ドラ', '1', '近本', 'プロ', '先頭打者', '弾'],
#  ['座布団', '処罰', '厳戒', '国技館'],
#  ['サニブラウン', '200日', '歴代', '3位'],
#  ['MLB', '投手', 'ら', '佐々木', '評'],
#  ['朝乃', '山', '快勝', '笑顔', 'V'],
#  ['J1', '神戸', '監督', 'ンゲル', '氏', '浮上'],
#  ['ヤクルト', '2年ぶり', '悪夢', '10連敗'],
#  ['朝乃', '山', '栃ノ心', '一言'],
#  ['サーフィン', '五十嵐', '日本人', 'V'],
#  ['朝乃', '山', '恩師', '教え'],
#  ['メッセ', '9', '四死球', '球審', 'ボヤキ'],
#  ['朝乃', '山初', '優勝', '58年ぶり', '快挙'],
#  ['貴源治', '貴', '富士', '双子', '同時', 'V'],
#  ['SB', '米', 'ドラ', '1', '右腕', '契約合意'],
#  ['巨人', 'スパイ', '広島', '長野', '心配'],
#  ['頭部', '死球', '一岡', 'G', '中島', '謝罪'],
#  ['香川', '最終戦', '拍手'],
#  ['錦織', '世界', '30', '40位', '以降', '脅威'],
#  ['画面', 'スカイウォーカー', '大谷'],
#  ['アテネ', '金', '鈴木桂治', '氏', '復帰'],
#  ['栃ノ心', '判定負け', '抗議殺到'],
#  ['38歳', '鈴木', '桂治', '氏', '現役復帰'],
#  ['巨人戦', '乱闘騒ぎ', '警告試合'],
#  ['ウグイス嬢', '恒例', '杉谷', 'いじり'],
#  ['栃ノ心'],
#  ['重量挙げ', '三宅', '涙', '途中', '棄権'],
#  ['異例', 'J1', '神戸', '会長', '激励'],
#  ['睡眠', '2時間半', '敗戦', '大学野球'],
#  ['17歳', '久保建英', 'コパアメリカ'],
#  ['五輪', 'チケ', '28日', '方', '復習'],
#  ['バド', '日本', '韓国', '人', '監督', '教え'],
#  ['甲子園', '球児', 'ありか'],
#  ['錦織', '仏', '王者', 'ナダル', '山'],
#  ['清宮', '1軍', '昇格', '監督'],
#  ['日ハム', '杉谷', 'まさ', '打席', '弾'],
#  ['大谷', '企画', '通訳', 'Tシャツ', '好評'],
#  ['J1', 'VAR', '21年度', '導入'],
#  ['森保', 'J', '川島', '岡崎', '復帰', '理由'],
#  ['大坂', '境地', '仏'],
#  ['17歳', '久保建英', 'A代表', '初招集'],
#  ['武豊', '仏オークス', '経緯'],
#  ['清宮', '1軍', '昇格', '最短', '24日'],
#  ['2022年', 'W杯', '参加', '国', '拡大', '見送り'],
#  ['東京五輪', 'ボクシング', '存続'],
#  ['青木', 'NPB', '史上', '最速', '1500', '安打'],
#  ['本田圭佑', '規格外', '1年'],
#  ['物言い', '珍', '説明', '場内', '混乱'],
#  ['鉄剤', '注射', '陸連', '説明', '要求'],
#  ['羽生結弦', '急成長', '新星'],
#  ['ボール', '時代', '右打者', '有利'],
#  ['羽生結弦', '急成長', 'ゾウ'],
#  ['逸ノ城', '12日目', '再出場'],
#  ['SB', '米', 'ドラ', '1', '衝撃', '賛否'],
#  ['井上尚弥', '最強', 'ランク', '4位'],
#  ['井上尚弥', '階級', 'ランク', '4位'],
#  ['大谷', '笑顔', 'ぇじょうぶだ'],
#  ['大谷', '超回復', '8戦', '連続', 'スタメン'],
#  ['ACL', '浦和', 'GS', '突破', '川崎', '敗退'],
#  ['カープ', '首位', '驚異', '的', '巻き返し'],
#  ['JFA', '重大', '処分', '非公開'],
#  ['準決', '前', '激怒', '井上尚弥'],
#  ['SB', '米', '1', '巡', '目', '指名', '右腕', '獲得'],
#  ['G', '菅野', '腰', '違和感', '登録', '抹消'],
#  ['大谷', 'もん絶', '手', '150キロ', '直撃'],
#  ['近鉄', '小玉明利', 'さん', '死去'],
#  ['本田圭佑', 'J', '復帰', '可能性'],
#  ['ダル', '3失点', '勝ち'],
#  ['F1', '王者', 'ニキ・ラウダ', '氏', '死去'],
#  ['本田圭佑', 'メルボルン', 'V', '退団', '発表'],
#  ['大相撲', '関取', '史上初', '珍', '手'],
#  ['上原', '引退', '個性派', '21年間'],
#  ['大谷翔平', '7戦', '連続', 'スタメン'],
#  ['松井秀喜', '氏', '上原', '拍手'],
#  ['誤審', '主審', '2週間', '割り当て', '停止'],
#  ['松坂', '上原', '特別', '投手'],
#  ['敬遠', '涙', '上原', '引退', '足跡'],
#  ['葛藤', '上原', '会見', '涙'],
#  ['上原', '引退', 'G', '阿部'],
#  ['神', '上原', '米', '活躍'],
#  ['無駄', '上原', '投球', '取材'],
#  ['上原', '引退', '心', '中'],
#  ['井上尚弥', '修正', '力'],
#  ['ザギトワ', 'さん', '無免許運転', '疑い'],
#  ['雄星', '本拠地', '初勝利'],
#  ['貴景勝', '1日', '休場'],
#  ['G', '上原', '引退', '今'],
#  ['DF', '長友', 'フル出場', 'リーグ連覇'],
#  ['G', '上原', 'シーズン', '途中', '引退'],
#  ['井上尚弥', '階級', '可能性'],
#  ['ハム', '2軍', '胃腸炎', 'ダウン'],
#  ['貴景勝', '黒星', '再出場'],
#  ['男子', '100m', '伏兵', '10秒', '04', '4位'],
#  ['体操', '苦悩', '白井'],
#  ['J1', '神戸', '危機'],
#  ['エース', '谷川翔', 'NHK杯', 'V'],
#  ['3歳', '女王', 'ラヴズオンリーユー'],
#  ['男子', 'リレー', '日本', 'V', 'セイコー', 'GP'],
#  ['元貴', '親方', '出馬', '否定'],
#  ['DeNA', '久保', 'ホームレス', '危機'],
#  ['怪物', '井上', '1分', '修正', 'TKO'],
#  ['大谷', '今季', '2号', 'ファン', '総立ち'],
#  ['都', '少年サッカー', '夏', '試合', '禁止'],
#  ['同点弾', '直後', '香川', 'ミス', 'V', '消滅'],
#  ['井上尚弥', '全勝対決', 'TKO', '圧勝'],
#  ['ハム', '西川', '外野', '客', '傘'],
#  ['誤審', '湘南', '試合放棄'],
#  ['神戸', '7連敗', 'イニエスタ'],
#  ['体操', '村上', '特例', '選出', '示唆'],
#  ['錦織圭', '仏'],
#  ['村上茉愛', '直前', '自信'],
#  ['横山典弘', 'ダービー', '騎乗'],
#  ['SB', 'サファテ', '森'],
#  ['井上尚弥', '最強', '怪物'],
#  ['村上茉愛', '号泣', 'NHK杯', '棄権'],
#  ['大船渡', '佐々木', '敗退'],
#  ['甲子園', 'V', '右腕', 'プロ', '後悔'],
#  ['休場', '貴景勝', '8日目', '再出場'],
#  ['法大', 'FW', '上田綺世', 'A代表', '入り'],
#  ['沢村', '好投', 'コーチ', '涙', 'そう'],
#  ['大誤審', 'GK', '西川', '失点'],
#  ['錦織', '敗退', '仏', '反省'],
#  ['J1', '湘南', '誤審', '逆転勝利'],
#  ['G', '沢村', '復活', '981', '日', 'ぶり', 'セーブ'],
#  ['大坂', '負傷', '棄権', '親指'],
#  ['松坂', '同伴', '上重', 'アナ', '不快感'],
#  ['規律', '違反', '中日', '松坂', '謝罪'],
#  ['いす', '激怒', 'キリ', 'オス', '失格'],
#  ['トランプ氏', '正面', '升席', '確保'],
#  ['T-岡田', '2軍', '落ち', '失策'],
#  ['引退', '李', '小平'],
#  ['大山', '亜由美', 'さん', '死去', '五輪', '夢'],
#  ['大山', '亜由美', 'さん', '夢', '五輪'],
#  ['マエケン', '負傷者', 'リスト', '入り'],
#  ['八村塁', '4億円', '日本', '衝撃', '巨額'],
#  ['大山', '亜由美', 'プロ', '死去', '25歳'],
#  ['井上尚弥', '統一', '戦', '消滅', 'ピンチ'],
#  ['オリ山', '本', '悪夢', '自責', '2', '6失点'],
#  ['中日', '松坂', 'ペナルティー'],
#  ['DeNA', 'ロペス', '51年ぶり', '記録'],
#  ['清宮', '毎日', '試合', 'の'],
#  ['前田健太', '12', '奪三振', '全て', '空振り'],
#  ['一発病', '菅野', 'OB', '休養', '勧告'],
#  ['前田', '投打', '活躍', 'MLB', 'マルチ'],
#  ['貴景勝', '夏場所', '休場', '決定'],
#  ['大谷', '一塁', '手', 'よそ見', '珍', '出塁'],
#  ['春', '大山', '反響', '詩', '応え'],
#  ['阪神戦', '大炎上', 'G', '菅野', '異変'],
#  ['貴景勝', '右膝', '負傷', 'うめき声'],
#  ['3', '季', '目', 'MVP', '富樫勇樹', 'Bリーグ'],
#  ['ブッフォン', 'Jリーグ', '参戦', '浮上'],
#  ['大谷翔平', '2度', '走塁', '死', '反省'],
#  ['大谷', '打点', '勝利', '神話'],
#  ['大迫', '五輪', 'OA', '枠', 'クラブ', '拒否'],
#  ['女性騎手', '32年後', '恋'],
#  ['投手', '故障', '予防'],
#  ['大谷', '自ら', 'バット', 'ボーイ', '仕事'],
#  ['グリーズマン', '退団', 'バルサ'],
#  ['G', '坂本', '開幕', '連続', '出塁', 'ストップ'],
#  ['阪神', '261日', 'ぶり', '巨人戦', '勝利'],
#  ['今年', '30歳', '錦織', 'スタイル', '変更'],
#  ['ロッテ', '細谷', '内野手', '3', '捕手'],
#  ['先発', 'MF', '香川'],
#  ['闘魂三銃士', '興行', '消滅'],
#  ['大谷', '130m', '弾', '解説者', '脱帽'],
#  ['スイス', '名門', '降格', '客', 'ユニ', '没収'],
#  ['大谷', '特大', '1号'],
#  ['C大阪', '都倉', 'ケガ', '今季絶望'],
#  ['最下位', '低迷', 'DeNA', '3つ', '誤算'],
#  ['大谷', '復帰後', '初', '本塁打'],
#  ['89歳', '現役', '格闘技', '記者', '取材', '歴'],
#  ['宇佐美', '3年ぶり', 'G大阪', '復帰'],
#  ['競馬', '信用失墜', '騎乗停止', '処分'],
#  ['広島', '助っ人', '左腕', '一蘭'],
#  ['坂本勇', 'ネック', '腰', '爆弾'],
#  ['打率', '表示', 'イヤ', 'ドラ', '1'],
#  ['打率', '105', '苦悩', 'ドラ', '1', '藤原'],
#  ['モーグル', '伊藤みき', '引退'],
#  ['2人目', '9秒', '台', '100m', '代表', '誰'],
#  ['マー君', '3勝', '目', '7回', '73', '球', '快投'],
#  ['1敗', 'リバプール', 'V'],
#  ['原監督', '球', '三振', '岡本', '苦言'],
#  ['神戸', '6連敗', 'サポ', '1時間'],
#  ['平野歩夢', 'V', '空中', '技'],
#  ['J1', '神戸', '会長', '関与', '100%'],
#  ['男子', '1600m', 'リレー', '日本', '4位'],
#  ['17位', 'J1', '清水', '監督', '解任'],
#  ['12日', 'ソフトB', '観客', '75%', '女性'],
#  ['平野歩夢', '五輪', '一', '歩'],
#  ['春', 'マイル', '女王', 'ノームコア'],
#  ['平野歩夢', 'V', '強化', '指定', '確実'],
#  ['金本', '氏', '坂本勇', 'セ', '記録'],
#  ['9秒', '台', '通り', '走り'],
#  ['大谷', 'マルチ', '安打', '連勝', '貢献'],
#  ['陸上', 'サニブラウン', '9秒', '99'],
#  ['バトン', '乱れ', '悪夢', '緩み'],
#  ['大坂なおみ', '世界ランク1位'],
#  ['陸上', 'リレー', '日本', '失格'],
#  ['平野歩夢', '決勝', '五輪', '前進'],
#  ['白鵬', '母', '日本国籍', '取得', '理解'],
#  ['アルバルク東京', 'Bリーグ', '連覇'],
#  ['新体制', '鳥栖', '3ゴール', '快勝'],
#  ['FIFA', '代理人', '処分', '移籍', '影響'],
#  ['マエケン', '圧巻', '無失点', '4勝', '目'],
#  ['中日', '笠原', '不整脈', '原因', '特定'],
#  ['松ヤニ', '騒動', 'MLB', '投手', '不文律'],
#  ['今季', '出場', 'MF', '阪口', '選出'],
#  ['大坂', '世界', '1位', '景色'],
#  ['社団法人', '貴乃花', '道場', '設立'],
#  ['0', '5', '逆転', '巨人', '19得点'],
#  ['レスリング', '協会', '内', 'パワハラ'],
#  ['貴景勝', '異例', '懸賞', '300', '本'],
#  ['小平', 'ライバル', '李相花', '引退'],
#  ['なでしこ', 'W杯', '23人', '発表', '阪口', 'ら'],
#  ['イチロー', '引退', 'スクープ', '葛藤'],
#  ['SB', '北方', 'ド', '軍', 'マイナー契約'],
#  ['雄星', '松ヤニ', '疑惑', '同情', '声'],
#  ['五輪', 'チケ', '電話', '認証', '断念', '続出'],
#  ['大谷', '初安打', '223日', 'ぶり', 'マルチ'],
#  ['大坂', '敗退', '世界', '1位', '陥落', '危機'],
#  ['楽天', '銀次', '意表', '突き', 'サヨナラ打'],
#  ['雄星', '松ヤニ', '疑惑', 'ヤ', '軍', '黙認'],
#  ['五輪', 'チケ', 'アクセス', '殺到', '陳謝'],
#  ['ラグビー', 'W杯', '7割', '認知', '初'],
#  ['雄星', '松ヤニ', '使用', '疑惑', '米', '報道'],
#  ['大谷', '2戦', '9打席', '安打', '前向き'],
#  ['CL', '華麗', 'ステップ', '弾', '反響'],
#  ['五輪', 'チケ', '開始', 'アクセス集中'],
#  ['白鵬', '夏場所', '休場', '右腕', '負傷'],
#  ['東京五輪', 'チケット', '申込', '開始'],
#  ['大谷', 'ヒヤリ', '手術', '右肘', '死球'],
#  ['大谷', '先発', '第1打席', '3', '球', '三振'],
#  ['きょう', '五輪', 'チケ', '狙い', '目'],
#  ['レスター', '岡崎', '退団', '正式発表'],
#  ['大坂', '世界', '33位', '撃破', '8強', '入り'],
#  ['青木宣親', '頭部', '死球', '一触即発'],
#  ['がん', '手術', '阪神', '原口', '実戦復帰'],
#  ['ヒル', '吸血', '栃ノ心', '調整', '順調'],
#  ['復帰', '大谷', '安心'],
#  ['池江', 'HP', '開設', '負け', 'たくない'],
#  ['W杯', 'ラグビー', '協会', '長', '退任'],
#  ['池江', '公式', 'HP', '治療', '順調'],
#  ['大谷', '復帰', '安打', '豪快', '空振り'],
#  ['9日', '五輪', 'チケット', '注意', '点'],
#  ['大谷', '遊ゴロ', '221日', 'ぶり', '打点'],
#  ['速報', '大谷', '219日', 'ぶり', '復帰戦'],
#  ['リバプール', '奇跡', 'バルサ', 'CL', '敗退'],
#  ['大谷', '3番', 'DH', '先発', '打者', '復帰'],
#  ['広島', '会沢', 'FA', '取得', '慰留', '全力'],
#  ['誤審', '疑惑', 'モレノ', '氏', '持論', '展開'],
#  ['日大', '教職員', '理事長', 'ら', '提訴'],
#  ['判定', '問題', '広島', '監督', '制裁金'],
#  ['球', '直撃', 'ソフト', '上野', '全治', '3カ月'],
#  ['25年前', '教訓', 'F1', '珍', '事故'],
#  ['MLB', '投打', '114年', 'ぶり', '快挙'],
#  ['西武', 'コーチ', '育成選手', '契約'],
#  ['勲章', '授与', 'タイガー・ウッズ', '涙'],
#  ['東京五輪', '日本', '金', '予想', '31', '個'],
#  ['J', '神戸', 'イニエスタ', '復帰'],
#  ['大谷', 'あす', 'チーム', '合流'],
#  ['レアル', 'ベイル', '戦力外通告'],
#  ['白鵬', '理事長', 'みたい', '重鎮'],
#  ['大仁田厚', '愛弟子', '死去', '絶句'],
#  ['ワイルド', 'セブン', 'さん', '死去'],
#  ['判定', '問題', '広島', 'NPB', '回答'],
#  ['人類', '5回転', '宇野', '練習', '着手'],
#  ['巨人', '助っ人', '4人', '同時', '入れ替え'],
#  ['北口榛花', '衝撃', '一投', '日本新'],
#  ['MF', '久保', 'ら', '3人', '飛び級', 'A代表'],
#  ['川内優輝', '婚約', '者', 'アベック', 'V'],
#  ['長友', '香川', '日本人対決', '実現'],
#  ['女子', 'バレー', '栗原恵', '現役引退'],
#  ['NPB', '左腕', '最速', 'SB', '古谷', '160km'],
#  ['異例', '矢野', '監督', '本塁', '出迎え'],
#  ['ユベントス', '縦じま', 'ユニ', '終了'],
#  ['広島', '監督', '審判', '敵'],
#  ['好き', '選手', '鳥谷', '福留', '苦笑い'],
#  ['ルメール', 'ダービー', '騎乗'],
#  ['渡邉', '氏', 'たかが選手', '背景'],
#  ['SB', '育成', '出身', '6戦', '7', '盗', 'GW', '荒稼ぎ'],
#  ['アドマイヤマーズ', '3歳', 'マイル', '王'],
#  ['解任', 'J1', '鳥栖', '監督', '愛情', '永遠'],
#  ['ダル', '乱調', '球場', 'ブーイング'],
#  ['ダルビッシュ', '連続', '四球', '降板'],
#  ['J1', '鳥栖', '監督', '解任'],
#  ['広島', '判定', '巡り', 'NPB', '意見書'],
#  ['日韓', 'W杯', 'モレノ', '氏', '誤審'],
#  ['広島', '監督', '退場', '何'],
#  ['G', 'サヨナラ負け', '課題'],
#  ['J', '鳥栖', '6戦', '連続', '無得点', '5連敗'],
#  ['東京', '競馬', '天', '10', 'R', '以降', '中止'],
#  ['J', '神戸', 'ビジャ', '得点', '泥沼', '5連敗'],
#  ['処分', '解除', '日大', 'アメフト', '快勝'],
#  ['理由', '不明', 'J1', '鳥栖', '監督', 'ベンチ外'],
#  ['カープ', '緒方監督', '初回', '退場'],
#  ['菊池雄星', '10K', '快投', '勝利'],
#  ['井上尚弥', '異例', '報道', '締め出し'],
#  ['本田圭佑', '欧州', '複数', 'オファー'],
#  ['石川遼'],
#  ['女子', 'レスラー', '整形', '借金'],
#  ['J1', '広島', '幻のゴール', '判定', '激怒'],
#  ['阪神', '監督', 'サヨナラ打'],
#  ['柔道', '両者', '反則', '負け', '審判', '苦渋'],
#  ['金足', '農', '地区', '大会', '初戦', '大敗'],
#  ['波乱', '大阪桐蔭', '府', '予選', '敗退'],
#  ['鷹', '名手', '今宮', 'チーム', '美技'],
#  ['MF', '本田', 'メルボルン', 'V', '退団', '示唆'],
#  ['163km', '佐々木', '140', '理由'],
#  ['フィギュア', 'オズモンド', '引退'],
#  ['バルサ', 'MF', 'シャビ', '引退発表'],
#  ['163km', '佐々木', '効果', '立ち見', '客'],
#  ['石川遼', '初', '国内', 'ツアー', '棄権'],
#  ['低迷', 'J1', '神戸', 'シルバ', '獲得'],
#  ['腰痛', '石川遼', '顔'],
#  ['燕', 'バレンティン', '登録', '抹消'],
#  ['異例', '稀', '勢', '高安', '圧倒', '20勝'],
#  ['稀', '勢', '高', '安', '21番', '20勝', '圧倒'],
#  ['G', '岡本', '天井', '直撃', '打', '球場', '騒然'],
#  ['メジャー', 'ガラガラ', '試合', '反響'],
#  ['ドラ', '1', '近本', '快挙', '13戦', '連続', '安打'],
#  ['休み明け', '馬券'],
#  ['ダル', 'イチロー', '氏'],
#  ['退路', 'MLB', '営業マン'],
#  ['約束', '勝負', 'G', '監督'],
#  ['イチロー', '氏', '本拠地', '凱旋'],
#  ['マー君', '3敗', '目', '暴投', 'ソロ', '被弾'],
#  ['広島', '4連敗', '名手', '失策'],
#  ['メッシ', 'バルサ', '通算', '600', '得点'],
#  ['スペイン代表', 'GK', '緊急入院'],
#  ['プロ野球', '令和', '初'],
#  ['坂本', 'HR', '平成', '1号', '原監督', '笑顔'],
#  ['差別的', 'セメンヤ', '棄却'],
#  ['一触即発', 'SB', '武田', '危険球', '退場'],
#  ['SB', '武田', '令和', '初', '危険球', '退場'],
#  ['NPB', '歴代', '守備', 'うま', '助っ人'],
#  ['セナ', '氏', '死去', '25年', 'ライバル', '思い'],
#  ['ポドルスキ', '復帰', '騒動', '謝罪'],
#  ['G', '坂本勇', '令和', '1号'],
#  ['G', '坂本勇', '令和', '1号', '本塁打'],
#  ['レスナー', '総合格闘技', '引退'],
#  ['イチロー', '氏', '現在', '家事', '挑戦'],
#  ['長嶋茂雄', '氏', '元気', '姿'],
#  ['イチロー', '氏', 'マ', '軍', '選手', '指導', '役'],
#  ['平成最後', '野球', '記録', '一覧'],
#  ['全英', 'テニス', '賞金', '総額', '55億円'],
#  ['平成', '首位打者', '青木', '球界'],
#  ['美', '誠', 'ビデオ判定', '賛成'],
#  ['誤審', '騒動', '美', '誠', '次', '平常心'],
#  ['G', '石川', 'フェンス', '直撃', 'レフト', 'ゴロ'],
#  ['西岡', '戦力外', '後', '今'],
#  ['本田真凜', '胸中'],
#  ['強化選手', '真凜'],
#  ['堂安', '10億円', 'プーマ', '大型契約'],
#  ['柔道', '珍事', '両者', '反則', '負け'],
#  ['中国', '8戦', '全敗', '卓球', '課題'],
#  ['バス', '横転', 'チェコ', '代表', 'FW', '死亡'],
#  ['全日本', '柔道', 'ウルフ', '優勝'],
#  ['4連敗', 'J1', '神戸', '疑心暗鬼'],
#  ['辰吉丈一郎', '今', 'リング'],
#  ['中国', '代表監督', '2試合', '辞任'],
#  ['ルメール', '史上', '最少', '数', '1000', '勝'],
#  ['鳥栖', '9戦', '1得点', '金崎', 'ブチ', '切れ'],
#  ['観客', '暴行', 'ネイマール'],
#  ['Qちゃん', '弔辞', '最後', '手紙'],
#  ['まひ', '誤審', '問題', '抗議文', '送付'],
#  ['オリ', '1回', '6', '四球', 'オーナー', '激怒'],
#  ['想定外', '体操', 'リオ五輪', '組', '危機'],
#  ['疑惑の判定', '逆風', '早田', '悔しさ'],
#  ['まひ', '中国', '銀メダル'],
#  ['速報', 'まひ', '金メダル'],
#  ['ウインブライト', '海外', 'G1', '制覇'],
#  ['客', 'パンチ', 'ネイマール', '批判'],
#  ['J1', '鳥栖', '6億円', '赤字'],
#  ['4月16日', 'DeNA', '泥沼', '10連敗'],
#  ['最下位', '白井', '床', '採点', '疑問'],
#  ['ルメール', '8', '競走', '完全', '制覇'],
#  ['天皇賞春', 'フィエールマン', 'V'],
#  ['白井健三', '30人', '中', '30位'],
#  ['ソフト', '上野', '顔面骨折', '入院'],
#  ['ソフト', '上野', '打球', '顔面骨折'],
#  ['鯉', '党', '歓喜', '借金', '8', '11日', '完済'],
#  ['まひ', '52年ぶり', '金', '王手'],
#  ['錦織', '惜敗', '3年ぶり', '決勝'],
#  ['WBO', '女子', '佐伯', '衝撃', 'KO勝ち'],
#  ['斎藤佑', '高田', '脱帽'],
#  ['DeNA', '4年ぶり', '泥沼', '9連敗'],
#  ['内村航平', '左腕', '痛', '種目', '別', '棄権'],
#  ['斎藤佑', '無失点', 'ファン', '喝采'],
#  ['平成', '本塁打', '最多', '金本', '氏'],
#  ['必死', '内村', '盟友'],
#  ['雄星', '9', '球', '無失点', '降板'],
#  ['内村', '予選落ち', '体操', '界', '衝撃'],
#  ['2度', '珍事', '海外', 'PK', '反響'],
#  ['丹羽', '惜敗', 'メダル', '意識'],
#  ['石川', '吉村', '組', 'V', '連覇'],
#  ['卓球', '速報', '吉村', '石川', '組', '決勝'],
#  ['内村航平'],
#  ['内村', '東京五輪', '夢物語'],
#  ['栗原恵', 'JT', '退団', '今後', '未定'],
#  ['2軍', '調整', '藤浪', 'イップス', '懸念'],
#  ['内村', '全日本', '予選落ち'],
#  ['デゴイチ', '異名', '黒姫山', '死去'],
#  ['日本', 'ロッベン', '去就'],
#  ['伊調馨', '準決勝', '黒星'],
#  ['史上初', 'MLB', 'NFL', '1', '巡', '指名'],
#  ['大迫', 'Tweet', '陸連', '規定', '見直し'],
#  ['ポドルスキ', '暴言', 'J', '厳重注意'],
#  ['武豊', '香港', '日本馬', '勝算'],
#  ['南米選手権', '地上波'],
#  ['井川慶', '氏', '始球式', 'コンビ', '復活'],
#  ['甲斐野', '新人', '記録', '11試合', '0', '失点'],
#  ['張本智和', '157位', '号泣'],
#  ['長野', 'まさ', '痛恨', '本塁', '転倒'],
#  ['パラクライマー', 'SOS', '協会', '不信'],
#  ['G', '菅野', 'ぼう然', '初', '3', '連続', '被弾'],
#  ['白鵬', '師匠', '次', '全て'],
#  ['処分', '白鵬', '生まれ'],
#  ['真凜', '強化', '指定', '高橋', '復帰'],
#  ['処分', '一夜', '新生', '白鵬'],
#  ['村田諒太', '王者', 'ブラント', '再戦'],
#  ['高橋尚子', 'さん', '涙', '小出氏', '対面'],
#  ['内村航平', '首', '下', '全部'],
#  ['ウッズ', '13年ぶり', '日本', 'プレー'],
#  ['ウッズ', 'ZOZO', '選手権', '参戦'],
#  ['美', '誠', 'これだけ', '練習', '完敗'],
#  ['小出氏', '死去', '選手', '哲学'],
#  ['卓球', '女子', '中国', '24年'],
#  ['J1', '神戸', '三', '木谷会長', '介入', '否定'],
#  ['天敵', '完勝', '張本', 'ビックリ'],
#  ['大田', '5安打', 'わけ'],
#  ['水谷', '敗戦', 'メダル', '夢'],
#  ['9回', 'G', '被弾', '4戦', '連続', '完封'],
#  ['小出義雄', '氏', '死期'],
#  ['小出氏', '死去', '高橋尚子', 'さん'],
#  ['三本締め', '白鵬', 'けん責', '処分'],
#  ['高橋尚子', 'さん', '感謝'],
#  ['ミシェル・ウィー', '無期限', '休養'],
#  ['小出氏', '死去', '有森', 'さん', '心境', '吐露'],
#  ['小出氏', '死去', '根底'],
#  ['小出氏', '死去', '常識'],
#  ['消えた天才', '土井杏南', '光'],
#  ['Qちゃん', '育成', '小出義雄', '氏', '死去'],
#  ['マエケン', '乱調', '4回', '6失点', '降板'],
#  ['開始', '7秒', 'ゴール', 'プレミア', '最速'],
#  ['完全試合', '中', '杉浦', '交代', '賛否'],
#  ['大迫', '怒り', 'Tweet', '陸連', '反論'],
#  ['メドベ', '衣装', '不適切', '露', '論争'],
#  ['G', '小林', '4安打', '打率', '415'],
#  ['うそ', '中日', '監督', '納得'],
#  ['練習', '回避', '広島', '鈴木', '先発落ち'],
#  ['大仁田', '復帰'],
#  ['楽器', '10万', 'ドル', '野球カード'],
#  ['大迫傑', 'Twitter', '陸連', '苦言'],
#  ['夢', '公務員', 'SB', '泉', '1勝'],
#  ['大谷', '回復', '率', '85%', '監督', '説明'],
#  ['監督', '二岡智宏', '笑顔', '苦悩'],
#  ['バレー', '山口舞', '引退', '五輪', '銅'],
#  ['ポドルスキ', '謝罪', '少年', '暴言'],
#  ['GACKT', 'RIZIN', '解説', '引退', '宣言'],
#  ['ポドルスキ', '謝罪', '侮蔑的', '暴言'],
#  ['桐生', '100m', 'アジア選手権', 'V'],
#  ['水谷隼', '僕'],
#  ['中日', '戦', '判定', '確認'],
#  ['長州', '引退試合', '石井', '真壁', '出場'],
#  ['MF', '柴崎岳', '構想外', '復活'],
#  ['渡辺謙', '阪神', 'シャレ'],
#  ['錦織', '敗戦', '響き', '世界', '7位', '後退'],
#  ['イチロー', '氏', '年金', '2000万円', '超'],
#  ['井端', '氏', '好調', '巨人', '打線', '考察'],
#  ['パッキャオ', '天心'],
#  ['内柴正人', '氏', '総合格闘技', '参戦'],
#  ['塁審', '判定', '中日', '意見書', '提出'],
#  ['天心', 'パッキャオ', '刺客', 'KO'],
#  ['12歳', '高飛び込み', '最年少', 'V'],
#  ['けが', 'ロッテ', '中村', '志願', '代打'],
#  ['塁審', 'セーフ', '判定'],
#  ['水谷', '張本', 'くじ運', '恨み'],
#  ['G', '亀井', '強肩', '披露', '右', 'ゴロ', '記録'],
#  ['雄星', '初勝利', '天国', '父'],
#  ['コーチ', '衝突', 'ロッテ', '中村', 'けが'],
#  ['長友', 'ヘッド', '移籍後', '初ゴール'],
#  ['史上初', 'C', 'ロナ', '英西', '伊', 'L', '優勝'],
#  ['マー君', '2勝', 'HR', '監督', '退場'],
#  ['斎藤佑樹', 'ジム', '通い', '生きがい'],
#  ['天心', '挑発', 'ベジータ', '技'],
#  ['広島', '松山', '頭', '死球', '球場', '騒然'],
#  ['神戸', '3連敗', '痛恨', 'ミス', 'PK', '献上'],
#  ['波乱', '選抜', 'V', '東邦', '県', '初戦敗退'],
#  ['子供', 'レスラー', '大谷', '信念'],
#  ['原監督', 'グータッチ', '理由'],
#  ['大谷', '術', '後', 'フリー', '柵', '9本'],
#  ['V', 'I', '不在', 'J1', '神戸', '非常事態'],
#  ['投壊', '守', '乱', '阪神', '32年ぶり', '屈辱'],
#  ['天心', '相手', 'パッキャオ', '刺客'],
#  ['ため息', '怒声', '阪神', '12失点', '大敗'],
#  ['斎藤佑樹', '状態', '昇格'],
#  ['白鵬', '春', '巡業', '育成', '意識'],
#  ['J1', '神戸', '解任', '辞任'],
#  ['平成', '五輪', 'アイドル'],
#  ['快挙', 'EL', '4強', '長谷部'],
#  ['中日', '好調', '閑散', 'ナゴヤ', 'D'],
#  ['雄星', '大谷', '米', '再会'],
#  ['ミヤネ屋', '春川', '氏', 'G', '助っ人'],
#  ['試合', '燕', '采配', '物議'],
#  ['ヤ', '軍', '3', 'A', '加藤', '活躍', '昇格', '視野'],
#  ['剛腕', '誕生', '岩手', '謎'],
#  ['阪神', '大勝', '8年ぶり', '1試合', '5発'],
#  ['日ハム', '金子', '球団', '白星'],
#  ['日ハム', '吉田正', 'シフト', '成功'],
#  ['日本', '10年', 'MF', 'ミキッチ', '引退'],
#  ['J', '神戸', 'サンペール', '獲得', '迷走'],
#  ['息子', '骨折', '少年野球', '憎悪'],
#  ['監督', '辞任', 'バルサ', '化', '采配', '影響'],
#  ['藤浪', '4月', '中', '実戦復帰', '志願'],
#  ['影響力', '100人', '大坂なおみ'],
#  ['CL', 'マンC', '幻', 'AT', '弾'],
#  ['苦難', 'SB', '外野手', 'いない'],
#  ['五輪', '自転車', '選考', '男女', '差', '訴え'],
#  ['ラグビー', '森', '名誉会長', '退任'],
#  ['老衰', 'ヒシアマゾン', '28歳'],
#  ['ATP', 'ファイナル', '東京', '開催'],
#  ['飛ぶボール', '説', 'G', '岡本', '反論'],
#  ['阪神', 'ガルシア', '背中', '爆弾'],
#  ['内海', '好投', '実戦', '復帰', '無失点'],
#  ['甲子園', '熱中症', '対策', '7000万円'],
#  ['アーモンドアイ', '凱旋門賞', '断念'],
#  ['ポドルスキ', '監督', '交代', '驚き'],
#  ['白鵬', '国籍離脱', '結果'],
#  ['マエケン', 'MLB', '40勝', '到達', '9人目'],
#  ['骨折', 'シャケトラ', '安楽死', '処分'],
#  ['白鵬', 'モンゴル', '国籍離脱', '申請'],
#  ['J1', '神戸', '監督', '意向', '契約解除'],
#  ['遼', '復活', 'ウッズ', 'コーチ', '断言'],
#  ['ウッズ', '特需', 'ボール', '欠', '品', '恐れ'],
#  ['五輪', '午前', '決勝', '選手', '第一'],
#  ['CL', 'アヤックス', '22年ぶり', '4強'],
#  ['ダル', '159', 'キロ', '死球', '3人', '直撃', '話題'],
#  ['ジョコ', '苦戦', 'ラケット', '破壊'],
#  ['涌井秀章', '9年ぶり', '四球', '完封'],
#  ['跳馬', '技', 'ヨネクラ', '命名'],
#  ['白鵬', '三本締め', '問題', '処分'],
#  ['黄金世代', 'トルシエ', '氏', '思い出'],
#  ['グータッチ', 'G', '戦士', '困惑'],
#  ['五輪', '日程', '発表', 'マラソン', '午前6時'],
#  ['菊池雄星', 'メジャー', '黒星'],
#  ['ウッズ', '復活', '優勝', '空白', '11年'],
#  ['楽天', '渡辺', '100', '死球', '記録', '王手'],
#  ['全校', '64人', '中学', 'ダンス', '全国', 'V2'],
#  ['雄星', '6回', '3失点', '初勝利'],
#  ['ダルビッシュ', '330日', 'ぶり', '白星'],
#  ['八村', '日本', '初', '1', '巡', '目', '指名', '予想'],
#  ['紀平', '元祖', '3回転', '半', '共通点'],
#  ['歴史', '的', '低迷', '丸', '広島'],
#  ['丸', 'ロス', '波及', '広島', '低迷'],
#  ['ボストンマラソン', '川内', '惨敗'],
#  ['バスケ', '八村塁', 'NBA', '挑戦', '表明'],
#  ['経験', '精度', '43歳', 'ウッズ', '強み'],
#  ['巨人', '異例', '4月', '大量', '入れ替え'],
#  ['星稜', '監督', '学校', '側', '指導', '禁止'],
#  ['ウッズ', 'V', '賭け', '配当', '1', '4億円', '困惑'],
#  ['代表', 'J', 'ファン', '熱'],
#  ['代表', '低迷', '平成', 'サッカー', '軌跡'],
#  ['八村塁', 'ハーフ', '子', '自信'],
#  ['ウッズ', '全米', '大統領', '絶賛'],
#  ['マー君', 'KO', '序盤', 'ツケ'],
#  ['ウッズ', '復活', 'V'],
#  ['原監督', '連日', '投壊', '異常'],
#  ['松山', 'ウッズ', 'V', '力', '人'],
#  ['キセキ', '凱旋門賞', '登録'],
#  ['マー君', '満塁', '被弾', '今季初', '黒星'],
#  ['ウッズ', 'マスターズ', '14年ぶり', 'V'],
#  ['J', '鳥栖', '最下位', '得点力不足'],
#  ['土屋太鳳', '皐月賞', '単勝', '的中'],
#  ['FC東京', '側', '久保', '交渉'],
#  ['広島', '開幕', '5', 'カード', '連続'],
#  ['宇野', '紀平', 'だんご3兄弟'],
#  ['皐月賞', '14年ぶり', '無敗', '制覇'],
#  ['誤審', 'マンU', 'PK', '判定', '物議'],
#  ['皐月賞', 'サートゥルナーリア', 'V'],
#  ['源田', 'フルイニング', '出場'],
#  ['SB', '今度', '投手', 'ミランダ', '離脱'],
#  ['マスターズ', 'ウッズ', 'V', '2打差'],
#  ['西武', '源田', '死球', '右手', '関節', '挫傷'],
#  ['紀平', '羽生', '振付師', 'タッグ'],
#  ['2', '満塁', '被弾', '虎', 'ファン', '8回'],
#  ['今夏', '久保', 'バルサ', '復帰', '地元紙'],
#  ['紀平', '乱調', '体', 'ガチガチ'],
#  ['水谷', '世界選手権', '最後', '明言'],
#  ['フィギュア', '日本', '2位', '連覇'],
#  ['ハム', '宮西', '史上初', '300', 'ホールド'],
#  ['速報', 'フィギュア', '国', '別', '女子', 'FS'],
#  ['筒香', '右肘', '死球', 'ファン', '怒り'],
#  ['163km', '佐々木', '朗', '希', '壁'],
#  ['輝', '星', '藤原', '2打席', '連続', '3', '球', '三振'],
#  ['サイン', '盗み', '抗議', '監督', '自粛'],
#  ['サンウルブズ', '将来', '像'],
#  ['マスターズ', '松山', 'ら', '決勝進出'],
#  ['雄星', '高3', '163', 'キロ'],
#  ['久保裕也', 'ブンデス', '初ゴール'],
#  ['虎', 'ファン', '貧打', '怒り'],
#  ['オリ', '送球', 'サヨナラ負け'],
#  ['宇野', '前人未到', '5回転', '意欲'],
#  ['広島', '泥沼', '5連敗', '主砲', '沈黙'],
#  ['宇野', '3位', '世界初', '大技', '失敗'],
#  ['速報', 'フィギュア', '国', '別', '男子', 'FS'],
#  ['小5', 'バレンシア', '光久', '8年'],
#  ['搬送', 'ロッテ', '高野', '脳', '異常'],
#  ['ロッテ', '高野', '頭部', '打球', '搬送'],
#  ['北尾光司', 'さん', '死去', '空白', '15年'],
#  ['オカダ・カズチカ', '三森', '結婚'],
#  ['源田', '衛藤', '交際', '西武'],
#  ['広島', '4連敗', '最下位', '丸', 'ロス'],
#  ['マスターズ', '松山', '3', '発進'],
#  ['打者', '大谷', '5月7日', '復帰'],
#  ['久保建英', 'U', '-2', '0'],
#  ['岡田', '自滅', '緒方監督', '降格', '即断'],
#  ['紀平', '点数', '高', 'すぎ', 'ビックリ'],
#  ['フィギュア', '国', '別', '宇野', 'SP', '3位'],
#  ['広島', '連夜', '悪夢', 'ファン', '罵声'],
#  ['速報', 'フィギュア', '国', '別', '男子', 'SP'],
#  ['紀平', 'SP', '1位', '世界最高', '83', '97点'],
#  ['速報', 'フィギュア', '国', '別', '女子', 'SP'],
#  ['買春', 'バスケ', '4選手', '処分', '解除'],
#  ['ダルビッシュ', '連敗', '力投'],
#  ['雄星', '4度目', '初勝利'],
#  ['大谷', '163', 'キロ', '佐々木'],
#  ['DeNA', '浜口', 'セ', '珍事', '完封'],
#  ['広島', '10回', '12失点', 'ファン', '涙'],
#  ['広島', '悪夢', '10回', '12失点'],
#  ['ルヴァン杯', '久保', '弾丸', 'FK', '炸裂'],
#  ['終結', 'ハリル', '氏', '1円', '裁判'],
#  ['マジック', 'J', '社長', '電撃', '辞任', '米'],
#  ['アマレス', '事故', '協会', '不信感'],
#  ['炭谷', '活躍', 'G', '捕手', '争い', '行方'],
#  ['バスケ', 'B1', '福岡', '資金', '難', '降格'],
#  ['ハリル', '氏', '側', 'JFA', '訴訟', '取り下げ'],
#  ['FW', '危険', 'プレー', '波紋'],
#  ['松山', 'マスターズ', '前', '不安'],
#  ['なでしこ', '悪癖', '独', 'ドロー'],
#  ['メイウェザー', '村田', '対戦', '興味'],
#  ['宮川', 'パワハラ', '告発', '後悔'],
#  ['虎', '梅野', '骨折', 'サイクル'],
#  ['騒動', '体操', '宮川', '復帰', '戦'],
#  ['広島', 'ジョンソン', '炎上', '3回', '6失点'],
#  ['FW', '浅野', '起用', 'NG', '会長', '言及'],
#  ['2人', '怪物', '大谷'],
#  ['長髪', '奨励', '野球', '強豪校', '挑戦'],
#  ['80本', '119', '本', 'セパ', 'HR', '急増'],
#  ['RIZIN', '契約', 'パッキャオ', '賛否'],
#  ['大坂なおみ', 'フェド', '杯', '代表', '辞退'],
#  ['輝', '星', '藤原恭大', 'プロ', '対決'],
#  ['八重樫', '完勝', '4階', '級', '制覇'],
#  ['イチロー', '宮内', '氏'],
#  ['G', '坂本勇', '丸', 'ダブル', '3番', '効果'],
#  ['池江', '日大', '入学', '水泳', '部', '入部'],
#  ['パッキャオ', 'RIZIN', '契約'],
#  ['SB', '柳田', '抹消', '肉離れ', '全治', '3週間'],
#  ['福原愛', 'さん', '第2子', '出産'],
#  ['大迫', '第2子', '半端'],
#  ['163', 'キロ', '衝撃', '捕手', '指'],
#  ['米', 'オシャレ', 'PK', '失敗', '物議'],
#  ['大迫', '復帰', '同点弾', 'アシスト'],
#  ['異常事態', '女子', '平泳ぎ', '代表', 'ゼロ'],
#  ['柔道', '決勝', '看板', '死闘'],
#  ['病', '復活', '競泳', '塩浦', '日本新'],
#  ['銀次', '1軍', 'マスク', '盗塁'],
#  ['張本', '右手', 'けが', '世界卓球', '不安'],
#  ['桜花賞', 'グランアレグリア', 'V'],
#  ['打率', '105', 'ドラ', '1', '藤原', '抹消'],
#  ['陸上', '五輪', '選考', '選手', 'ら', '悲鳴'],
#  ['カズ', '17歳', '35歳', '差', 'スタメン'],
#  ['マラドーナ', '氏', '怒り', '監督', '辞任'],
#  ['1分', '短く', 'ゴング', 'JBC', '処分', '方針'],
#  ['張本', '去年'],
#  ['広島', '大敗', '阪神', 'ほころび'],
#  ['球速', '163', 'キロ', '高3', '速度'],
#  ['RENA', '21日', 'RIZIN', '復帰戦'],
#  ['瞬間移動', '高3', '球速', '163', 'キロ'],
#  ['青木', '宣', '代打', '劇的', 'サヨナラ', '弾'],
#  ['阪神', '大敗', '8戦', '連続', '3得点', '以下'],
#  ['瀬戸大也', '2冠', 'エース', '存在感'],
#  ['地獄', '宮市亮', '26歳', '再起'],
#  ['柔道', '金', 'ベイカー', '五輪'],
#  ['大船渡', '佐々木', '163', 'キロ', '記録'],
#  ['バルサ', '今夏', '11選手', '放出'],
#  ['JOC', '会長', '報道', '山下', '氏', '困惑'],
#  ['プロ', '医学部', '卒', '左腕'],
#  ['完投', '菅野', '内海', '魂', '継承'],
#  ['菅野', '志願', '内海', 'ロッカー', '継承'],
#  ['雄星', '5回', '6失点', '初勝利'],
#  ['辰吉', 'Jr.', '127秒', 'TKO', '11連勝'],
#  ['自撮り', '原因', '珍', '失点', 'モロッコ'],
#  ['栄誉', '賞', '辞退', '球界', '2人目'],
#  ['貧打', 'オリ', '待望', '29回', 'ぶり', '得点'],
#  ['家長昭博', '日本代表', '後悔'],
#  ['明らか', 'ミス', 'ダル', '黒星', '反省'],
#  ['ダル', '恩師', '若生', '監督', '勇退'],
#  ['ダルビッシュ', '5回'],
#  ['なでしこ', '仏', '敗戦'],
#  ['オリ', '貧打', '深刻', '25回', '連続', '0', '行進'],
#  ['イチロー', '氏', '国民栄誉賞', '辞退'],
#  ['先発', '初勝利', 'G', 'ドラ', '1', '高橋', '快挙'],
#  ['栗山', '監督', '黒星', '斎藤佑'],
#  ['年俸', 'G', '普通', 'すき家'],
#  ['斎藤佑', '673', '日', 'ぶり', '白星'],
#  ['斎藤佑', '先発', '3失点', '降板'],
#  ['阪神', '陽気', 'ベンチ', 'コーチ', '案'],
#  ['判定', '13分', 'ウオッカ', '興奮'],
#  ['錦織', 'トップ', '10', '維持', 'の'],
#  ['センバツ', '外', '驚き', '逸材'],
#  ['MLB', '332', '億', '円', '男', '弾丸', 'HR'],
#  ['里崎', '氏', 'ファン', '苦言', '真意'],
#  ['東京五輪', 'テニス', '決勝', '3セット'],
#  ['暴力', 'フェンシングコーチ', '処分'],
#  ['落下', 'レスラー', '救急搬送'],
#  ['川内優輝', '驚き', '婚約', '会見'],
#  ['東邦', 'V', '腕', '打撃', '落合', '広澤', '級'],
#  ['競泳', '今井', '池江璃花子', '涙'],
#  ['DeNA', 'パットン', '連夜', '乱調'],
#  ['丸', '岡本', 'アベック', '弾', '4連勝'],
#  ['異例', 'マンC', '移籍', '板倉'],
#  ['虎', '梅野', '左足', '骨折', '疑い', '離脱'],
#  ['習志野', '疑惑', '星稜', '敬意'],
#  ['ダービー', 'ウオッカ'],
#  ['東邦', '平成', '初', '有終', 'V', '達成'],
#  ['決勝', '速報', '東邦', 'vs', '習志野'],
#  ['謎', 'まま', '明石', '商', '謎', '人'],
#  ['TT', 'vs', '美', '爆音', '応援'],
#  ['マー君', '7', 'K', '開幕', '連勝'],
#  ['DF', '長谷部', '独', '天職'],
#  ['ミスター', '復活', '昨年', 'ICU', '闘病'],
#  ['スカウト', 'センバツ', '逸材'],
#  ['巨人', '沢村', '1651', '日', 'ぶり', '先発'],
#  ['令和', '4冠', '王', '柳田', '3戦', '連発'],
#  ['G', 'ゲレーロ', '4試合', '打率', '583'],
#  ['丸', 'G', '移籍後', '1号', '両手', '丸'],
#  ['楽天', '戦', '一', '時', '中断', '雪', '球'],
#  ['東京', 'D', '長嶋茂雄', '氏', '歓声'],
#  ['長嶋茂雄', '氏', '10カ月', 'ぶり', '公', '場'],
#  ['東邦', '30年ぶり', '決勝', '5度目', 'V', '王手'],
#  ['燕', '痛手', '坂', '口', '指', '骨折', '離脱'],
#  ['センバツ', '速報', '東邦', 'vs', '明石', '商'],
#  ['習志野', '逆転勝ち', '初', '決勝進出'],
#  ['ディープ', '首', '痛み', '種付け', '中止'],
#  ['サイン', '盗み', '疑惑', '高野連', '直撃'],
#  ['センバツ', '速報', '明豊', 'vs', '習志野'],
#  ['カズ', '史上初', '3', '元号', '弾'],
#  ['ナイス', '俺', '斎藤佑', '平成'],
#  ['MF', '南野', '40m', '快走', '逆転', '弾'],
#  ['ガンキャノン', '甲斐', '型', '狙い'],
#  ['恐怖', '改革', '原監督', '采配'],
#  ['東北', '大谷', '級', '右腕', '日', '米', '注目'],
#  ['父', '遺言', '雄星', '葬儀'],
#  ['イチロー', '人望', '真意'],
#  ['格闘', 'ONE', '日本初', '上陸', '成功'],
#  ['久保', '残留', 'F', '東', '優勝', '現実味'],
#  ['智弁', '和', '9回', '痛恨', '1', '球'],
#  ['Qちゃん', '恩師', '指導', '者', '引退'],
#  ['岡崎', '今季', '終了', '後', '移籍', '明言'],
#  ['雄星', '父', '死去'],
#  ['明石', '商', 'サヨナラ勝ち', '初', '4強'],
#  ['白鵬', '右', '上腕', '筋肉', '部分', '断裂'],
#  ['速報', '明石', '商', 'vs', '智弁和歌山'],
#  ['東邦', '打線', '爆発', '30年ぶり', '4強'],
#  ['大阪杯', '北村友', '悲願', 'G1', '制覇'],
#  ['G1', '大阪杯', 'アルアイン', '復活', 'V'],
#  ['菊池雄星', '父', '雄治', 'さん', '死去'],
#  ['マエケン', '今季初', '先発', '初勝利'],
#  ['速報', '筑陽学園', 'vs', '東邦'],
#  ['明豊', '11回', 'サヨナラ', '初', '4強'],
#  ['ダル', '自己', '最悪', '7', '四球'],
#  ['速報', '明豊', 'vs', '龍谷大平安'],
#  ['エース', '奮闘', '習志野', '逆転', '4強'],
#  ['米', '大学', 'バスケ', '八', '村', '4強'],
#  ['伊東純也', '豪快', 'ミドル', '躍動'],
#  ['速報', '市', '和歌山', 'vs', '習志野'],
#  ['バスケ', '男子', '44年ぶり', '五輪', '決定'],
#  ['アーモンドアイ', 'ドバイ', 'V'],
#  ['オコエ', '逆転', '弾', '監督', '恩返し'],
#  ['雨中', '戦い', '智弁和歌山', '8強'],
#  ['速報', '啓', 'vs', '智弁和歌山'],
#  ['涙', '塚原氏', '騒動'],
#  ['トーレス', '不在', '鳥栖', '皮肉'],
#  ['啓', 'vs', '智弁和歌山', '雨', '中断'],
#  ['雄星', '初勝利', '抑え', '被弾'],
#  ['明石', '商', '猛', '打', '大分', '8強'],
#  ['センバツ', '速報', '明石', '商', 'vs', '大分'],
#  ['東邦', '12得点', '名門', '対決'],
#  ['根絶', '難問', 'サイン', '盗み', '各校', '反応'],
#  ['センバツ', '速報', '広陵', 'vs', '東邦'],
#  ['サイン', '監督', '水掛け論'],
#  ['中田翔', '意地', 'サヨナラ満塁弾'],
#  ['古巣', '洗礼', 'G', '丸', '4', '連続三振'],
#  ['斎藤佑', '開幕戦', '無失点', '中継ぎ'],
#  ['羽生結弦', '2', '-3', 'カ月', '加療', '必要'],
#  ['速報', 'プロ野球', 'セ', 'パ', '開幕戦'],
#  ['競泳', '藤森', 'ドーピング', '陽性'],
#  ['横綱', '双羽黒', '北尾', 'さん', '死去'],
#  ['暴力', '法大', '野球部', '監督', '謹慎'],
#  ['筑陽学園', '接戦', '初', '8強'],
#  ['サイン', '習志野', '監督', '否定'],
#  ['打', '9点', '快勝', '龍谷大平安', '8強'],
#  ['速報', '龍谷大平安', 'vs', '盛岡大付'],
#  ['明豊', '札幌大谷', '初', '8強'],
#  ['星稜', '高野連', '謝罪', '抗議'],
#  ['速報', '明豊', 'vs', '札幌大谷'],
#  ['白鵬', '謝罪', '2度目', '呼び出し'],
#  ['ダル', '聖子', 'さん', '結婚', '変化'],
#  ['サイン', '盗み', 'ルール', '確認', '契機'],
#  ['ロッテ', '藤原', '根尾', '努力', '晩成', '型'],
#  ['羽生結弦', '最大', 'スター', 'IOC'],
#  ['Dear', 'Ichiro', '同僚', '全面広告'],
#  ['マー君', '4度目', '開幕戦', '白星'],
#  ['美', '爆音', '異例', '苦情'],
#  ['習志野', 'サイン', '盗み', '疑惑', '波紋'],
#  ['三本締め', '白鵬', '処分', '検討'],
#  ['習志野', 'サイン', '星稜', '激怒'],
#  ['V', '候補', '星稜', '惜敗', '奥川', '10K'],
#  ['熊本西', '友', '春'],
#  ['センバツ', '速報', '星稜', 'vs', '習志野'],
#  ['市', '和歌山', '52年ぶり', '8強', '1番', '乗り'],
#  ['HR', '量産', '中', '大田', '今年', '30発'],
#  ['速報', '市', '和歌山', 'vs', '高松商'],
#  ['智弁和歌山', '中谷', '監督', '初陣'],
#  ['けん制球', 'ゼロ', 'DeNA', '山崎', '謎'],
#  ['貴景勝', '横綱', '可能性'],
#  ['敗退', '国士舘', '学校行事', '悲劇'],
#  ['速報', '熊本西', 'vs', '智弁和歌山'],
#  ['60分', '森保', 'J', '疑問符'],
#  ['ダルビッシュ', '37歳', '引退'],
#  ['中日', '開幕', 'コンビ', '12球団', '一'],
#  ['南米選手権', '17歳', '久保', '候補'],
#  ['美', '爆音', '応援', '対戦', '校', '脅威'],
#  ['頑固', '夫', 'イチロー', '愛妻'],
#  ['偏食', '改善', 'イチロー', '妻'],
#  ['横浜', '監督', '近藤昭仁', '氏', '死去'],
#  ['啓', '必勝', '継投', 'リレー', '初勝利'],
#  ['井岡一翔', '1年半', 'ぶり', '国内', '復帰'],
#  ['速報', '桐蔭学園', 'vs', '啓', '新'],
#  ['速報', '大分', 'vs', '松山聖陵'],
#  ['明石', '商', '10K', '完投', '国士', '館'],
#  ['貴景勝', '口上', '武士道精神'],
#  ['カブス', '田沢', 'クビ'],
#  ['速報', '明石', '商', 'vs', '国士舘'],
#  ['元貴', '親方', '貴景勝', '健闘'],
#  ['香川真司', '実感', '転換期'],
#  ['ポスト', '大迫', '不発', '三銃士', '頼み'],
#  ['MF', '中島', '股', '抜き', 'ゴール'],
#  ['森保', 'J', '勝利', '中島翔哉', '決勝弾'],
#  ['代打', '要員', '巨人', '阿部', '土俵際'],
#  ['UFC', 'マクレガー', '引退', '発表'],
#  ['東邦', '応援', '大阪桐蔭', 'ブラバン'],
#  ['楽天', '浜矢', 'DeNA', '熊原', 'トレード'],
#  ['墜落', 'サラ', '選手', '移籍金', '拒否'],
#  ['センバツ', '速報', '東邦', 'vs', '富岡西'],
#  ['広陵', '河野', '8K', '完封', '最速', '150km'],
#  ['ボクシング', 'リオ', '不正', '判定'],
#  ['06', '年', 'WBC', '不安', 'イチロー'],
#  ['速報', '広陵', 'vs', '八戸学院光星'],
#  ['筑', '陽', '接戦', '甲子園', '初勝利'],
#  ['速報', '筑陽学園', 'vs', '福知山成美'],
#  ['G', '開幕', 'ローテ', '6番', '目', 'ドラ', '1', '高橋'],
#  ['3番', '丸', '岡本', 'さん', '前', '恐縮'],
#  ['敗退', '横浜高', '握手', '物議'],
#  ['G', '開幕', 'ローテ', '5人目', '発表'],
#  ['白鵬', '三本締め', '横審', '苦言'],
#  ['札幌第一', '24', '失点', '5人', '継投'],
#  ['24', '5', '山梨学院', '記録', '的', '大勝'],
#  ['白鵬', '稀', '勢', '気持ち'],
#  ['速報', '山梨学院', 'vs', '札幌', '第一'],
#  ['羽生結弦', 'けが', '国', '別', '対抗', '欠場'],
#  ['マー君', '妻', '第2子', '妊娠', '報告'],
#  ['水谷隼', '葛藤', '球'],
#  ['ドイツ', '劇的', '勝利', 'EURO', '予選'],
#  ['速報', '津田学園', 'vs', '龍谷大平安'],
#  ['早田ひな', '国際大会', '2', '連続', 'V'],
#  ['本田', '監督', '東京五輪', '出場', '消滅'],
#  ['最速', '135km', '課題', '上原', '2軍', '決定'],
#  ['白鵬', '重傷', '筋肉'],
#  ['小林', '陵', '日本', '最長', '252m', '13勝', '目'],
#  ['平成最後', '非情', '大関', '交代', '劇'],
#  ['FK', '弾', '久保', '2得点', 'U', '-2', '2連勝'],
#  ['広島', '会沢', '顔面', '死球', '球場', '騒然'],
#  ['羽生', '宣言', '全て', '4回転'],
#  ['貴景勝', '大関昇進', '確実'],
#  ['白鵬', '42回目', '優勝', '最多', '更新'],
#  ['1失点', '完投', '札幌大谷', '初陣', '1勝'],
#  ['非情', '通告', 'カブス', '田澤', '解雇'],
#  ['高松宮記念', '449', '万', '馬券', '波乱'],
#  ['高松宮記念', 'ミスターメロディ', 'V'],
#  ['珍', '試合', '10得点', '投手', '自責', '0'],
#  ['速報', '米子', '東', 'vs', '札幌大谷'],
#  ['横浜', 'エース', '3回', 'KO', '初戦敗退'],
#  ['川内', '忍者', '公務員', 'ラストラン'],
#  ['センバツ', '速報', '明豊', 'vs', '横浜'],
#  ['初回', '7得点', '習志野', '快勝', '発進'],
#  ['センバツ', '速報', '日章', 'vs', '習志野'],
#  ['マー君', 'もの', '奥川'],
#  ['大坂', '勝利', '目前', '逆転負け'],
#  ['2位', '羽生', '負け', '死', '同然'],
#  ['チェン', '圧巻', '世界最高', '323', '42点'],
#  ['羽生', '300点', '超', '2位'],
#  ['貴景勝', '大関', '取り', '痛恨', '黒星'],
#  ['速報', '世界フィギュア', '男子', 'FS'],
#  ['星稜', '奥川', '履正社', '17K', '完封'],
#  ['根尾', '方向', 'プロ', '本塁打'],
#  ['センバツ', '速報', '履正社', 'vs', '星稜'],
#  ['高松商', 'エース', '13', '奪三振', '完封'],
#  ['52歳', 'FW', 'カズ', '2年ぶり', 'スタメン'],
#  ['速報', '高松商', 'vs', '春日部共栄'],
#  ['延長', 'サヨナラ', '市', '和歌山', '勝利'],
#  ['イチロー', '父', '子供', '力'],
#  ['開幕戦', '呉', 'vs', '市', '和歌山', '延長'],
#  ['SB', '中村晃', '自律神経失調症'],
#  ['イチロー', 'ゴジラ', '流', '惜別'],
#  ['松井秀喜', '氏', 'イチロー', '引退'],
#  ['センバツ', '速報', '呉', 'vs', '市', '和歌山'],
#  ['裏切り者', '批判', 'メドベ', '意地', '銅'],
#  ['オリ', '監督', '怒り', '山岡', '開幕', '白紙'],
#  ['引退', '失礼'],
#  ['錦織', 'まさ', '初戦敗退'],
#  ['森保', 'J', '敗戦', '香川', 'ら', '投入', '0得点'],
#  ['紀平', '巻き返し', '4位', '今', '満足'],
#  ['快挙', 'カザフ', '19歳', '4回転', '成功'],
#  ['ザギトワ', '圧巻', '初', '世界', '女王'],
#  ['渡辺', '主筆', '巨人', 'V'],
#  ['イチロー', '敬意', '松坂', '会見', '中止'],
#  ['ネリ', '井上尚弥', '挑戦', '希望'],
#  ['イチロー', '米', '殿堂入り', '確実'],
#  ['速報', '世界フィギュア', '女子', 'FS'],
#  ['サンウルブズ', '条件', '除外'],
#  ['イチロー', '米メディア', '絶賛'],
#  ['古巣', 'オリ', '51', '永久欠番', '検討'],
#  ['イチロー', '国民栄誉賞', '検討'],
#  ['イチロー', '引退', 'カズ', '喪失感'],
#  ['イチロー', '年齢', '壁'],
#  ['イチロー', '17歳', '愛犬', '一', '弓', '支え'],
#  ['イチロー', '監督', '絶対無理'],
#  ['イチロー', '引退', 'メジャー', '衝撃'],
#  ['イチロー', '草野球'],
#  ['羽生', 'V', '条件', 'ノーミス', '加点'],
#  ['イチロー', '節', '全開', '85分', '会見'],
#  ['GM', 'イチロー', '生涯', '役職'],
#  ['イチロー', '一番', 'の', '妻'],
#  ['今日', '元', 'イチロー'],
#  ['イチロー', '会見', '引退', '後悔'],
#  ['イチロー', '45歳', '150日', '決断'],
#  ['イチロー', '現役引退', '正式', '表明'],
#  ['イチロー', 'ハグ', '雄星', '号泣'],
#  ['イチロー', '歓声', '交代'],
#  ['羽生', '復帰', '戦', 'SP', '3位', '宇野', '6位'],
#  ['菊池', '途中', '降板', '白星'],
#  ['イチロー', '引退', 'MLB', '公式'],
#  ['イチロー', '第一線', '意向'],
#  ['ロッテ', '1位', '藤原', '開幕', '1軍', '入り'],
#  ['速報', '世界フィギュア', '男子', 'SP'],
#  ...]

# %%
model = Word2Vec(wakati_list, size=100, window=5, min_count=1, workers=4)
model.save("word2vec.model")

# %%
# sim = model.similarity("マー君", "イチロー")

synonym = model.most_similar(positive="ももクロ")
synonym
# Out:
# /home/y-watanabe/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# [('洞窟', 0.35756874084472656),
#  ('高田', 0.3421747386455536),
#  ('空振り', 0.3156339228153229),
#  ('安楽死', 0.31274357438087463),
#  ('発売前', 0.30569547414779663),
#  ('アウト', 0.2991495132446289),
#  ('燕', 0.29906147718429565),
#  ('江東区', 0.2972562611103058),
#  ('銀行', 0.29091835021972656),
#  ('爆破予告', 0.2873806953430176)]

# %%
dictionary = Dictionary(wakati_list)
print(dictionary.token2id)
# Out:
# {'ももクロ': 0, 'マー君': 1, '敗戦': 2, '観戦': 3, 'さん': 4, '娘': 5, '平尾誠二': 6, '父': 7, '20日': 8, 'U': 9, 'サッカー': 10, '大人': 11, '必要': 12, 'DH': 13, 'MLB': 14, '候補': 15, '入り': 16, '大谷': 17, '球宴': 18, '興奮': 19, '1軍': 20, '復帰': 21, '来月21日': 22, '松坂': 23, '一番': 24, '人生': 25, '初戦突破': 26, '大坂': 27, '緊張': 28, '仏': 29, '坂': 30, '大': 31, '大逆転': 32, '80年': 33, '五輪': 34, '代表': 35, '幻': 36, '死去': 37, '氏': 38, '笹田': 39, '1回戦': 40, 'OP': 41, '大坂なおみ': 42, 'DF': 43, 'ら': 44, 'レアル': 45, '八百長': 46, '逮捕': 47, '後任': 48, '浦和': 49, '監督解任': 50, '組長': 51, '回復': 52, '確か': 53, '羽生結弦': 54, '世界陸上': 55, '代表復帰': 56, '川内優輝': 57, '丸刈り': 58, '体': 59, '青木宣親': 60, '鼓舞': 61, '257日': 62, 'ぶり': 63, '中日': 64, '実戦': 65, '登板': 66, '188cm': 67, 'SB': 68, '下手': 69, '右腕': 70, '座布団': 71, '相撲': 72, '罪': 73, '克服': 74, '赤土': 75, '二': 76, '失敗': 77, '安打': 78, '技あり': 79, '盗': 80, 'きょう': 81, 'チケ': 82, '申し込み': 83, 'ドラフト': 84, '優先': 85, '変更': 86, '指名': 87, '権': 88, '100': 89, '2軍': 90, '戦': 91, '昇格': 92, '星': 93, '条件': 94, '球': 95, '輝': 96, '審判': 97, '横審': 98, '混乱': 99, '苦言': 100, '部': 101, 'V': 102, 'クビトバ': 103, '全豪': 104, '棄権': 105, '2ラン': 106, 'きっかけ': 107, '丸': 108, '広島': 109, '浮上': 110, '4月': 111, '覚醒': 112, '26.3%': 113, '夏場所': 114, '大統領': 115, '視聴率': 116, '93倍': 117, 'ダービー': 118, '伏兵': 119, '単勝': 120, 'クーラー': 121, '山': 122, '朝乃': 123, '親方': 124, '何': 125, '本田圭佑': 126, '6勝': 127, 'マエケン': 128, '今季': 129, '先発': 130, '目': 131, '3発': 132, 'メキシコ': 133, '快勝': 134, 'J': 135, 'ビスマルク': 136, 'ポーズ': 137, '錦織圭': 138, 'FW': 139, 'ロニー': 140, '母国': 141, '試合中': 142, 'そう': 143, '山かわ': 144, '御嶽海': 145, '速報': 146, 'ゴール': 147, '主審': 148, '抗議': 149, '蘭': 150, '授与': 151, '来年以降': 152, '杯': 153, '米大統領': 154, 'G': 155, 'コーチ': 156, '元木': 157, '判断': 158, '制覇': 159, '浜中': 160, '真っ白': 161, '頭': 162, 'J1': 163, '神戸': 164, '脱出': 165, '連敗': 166, 'ロジャーバローズ': 167, '-3': 168, '0': 169, '伊藤雅雪': 170, '王座': 171, '痛恨': 172, '陥落': 173, '1': 174, 'ドラ': 175, 'プロ': 176, '先頭打者': 177, '弾': 178, '近本': 179, '処罰': 180, '厳戒': 181, '国技館': 182, '200日': 183, '3位': 184, 'サニブラウン': 185, '歴代': 186, '佐々木': 187, '投手': 188, '評': 189, '笑顔': 190, 'ンゲル': 191, '監督': 192, '10連敗': 193, '2年ぶり': 194, 'ヤクルト': 195, '悪夢': 196, '一言': 197, '栃ノ心': 198, 'サーフィン': 199, '五十嵐': 200, '日本人': 201, '恩師': 202, '教え': 203, '9': 204, 'ボヤキ': 205, 'メッセ': 206, '四死球': 207, '球審': 208, '58年ぶり': 209, '優勝': 210, '山初': 211, '快挙': 212, '双子': 213, '同時': 214, '富士': 215, '貴': 216, '貴源治': 217, '契約合意': 218, '米': 219, 'スパイ': 220, '巨人': 221, '心配': 222, '長野': 223, '一岡': 224, '中島': 225, '死球': 226, '謝罪': 227, '頭部': 228, '拍手': 229, '最終戦': 230, '香川': 231, '30': 232, '40位': 233, '世界': 234, '以降': 235, '脅威': 236, '錦織': 237, 'スカイウォーカー': 238, '画面': 239, 'アテネ': 240, '金': 241, '鈴木桂治': 242, '判定負け': 243, '抗議殺到': 244, '38歳': 245, '桂治': 246, '現役復帰': 247, '鈴木': 248, '乱闘騒ぎ': 249, '巨人戦': 250, '警告試合': 251, 'いじり': 252, 'ウグイス嬢': 253, '恒例': 254, '杉谷': 255, '三宅': 256, '涙': 257, '途中': 258, '重量挙げ': 259, '会長': 260, '激励': 261, '異例': 262, '2時間半': 263, '大学野球': 264, '睡眠': 265, '17歳': 266, 'コパアメリカ': 267, '久保建英': 268, '28日': 269, '復習': 270, '方': 271, 'バド': 272, '人': 273, '日本': 274, '韓国': 275, 'ありか': 276, '球児': 277, '甲子園': 278, 'ナダル': 279, '王者': 280, '清宮': 281, 'まさ': 282, '打席': 283, '日ハム': 284, 'Tシャツ': 285, '企画': 286, '好評': 287, '通訳': 288, '21年度': 289, 'VAR': 290, '導入': 291, '岡崎': 292, '川島': 293, '森保': 294, '理由': 295, '境地': 296, 'A代表': 297, '初招集': 298, '仏オークス': 299, '武豊': 300, '経緯': 301, '24日': 302, '最短': 303, '2022年': 304, 'W杯': 305, '参加': 306, '国': 307, '拡大': 308, '見送り': 309, 'ボクシング': 310, '存続': 311, '東京五輪': 312, '1500': 313, 'NPB': 314, '史上': 315, '最速': 316, '青木': 317, '1年': 318, '規格外': 319, '場内': 320, '物言い': 321, '珍': 322, '説明': 323, '注射': 324, '要求': 325, '鉄剤': 326, '陸連': 327, '急成長': 328, '新星': 329, 'ボール': 330, '右打者': 331, '時代': 332, '有利': 333, 'ゾウ': 334, '12日目': 335, '再出場': 336, '逸ノ城': 337, '衝撃': 338, '賛否': 339, '4位': 340, 'ランク': 341, '井上尚弥': 342, '最強': 343, '階級': 344, 'ぇじょうぶだ': 345, '8戦': 346, 'スタメン': 347, '超回復': 348, '連続': 349, 'ACL': 350, 'GS': 351, '川崎': 352, '敗退': 353, '突破': 354, 'カープ': 355, '巻き返し': 356, '的': 3 ...

# %%
vec = dictionary.doc2bow(['本田圭佑', 'メルボルン', 'V', '退団', '発表'])
print(vec)
# Out:
# [(102, 1), (126, 1), (386, 1), (387, 1), (388, 1)]

# %%
dense = []
for wakati in wakati_list:
    vec = dictionary.doc2bow(wakati)
    dense.append(list(matutils.corpus2dense([vec], num_terms=len(dictionary)).T[0]))

# %%
dense[0][0]
# Out:
# 1.0

# %%
X = dense
Y = [0 if i < 1000 else 1 for i in range(2000)]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)

# %%
random_forest = ensemble.RandomForestClassifier(max_depth=10)
random_forest.fit(X_train, Y_train)
random_forest.score(X_test, Y_test)
# Out:
# /home/y-watanabe/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.65
